# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model = 'gemma3n:e4b')

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
from IPython.display import Markdown, display

display(Markdown(ai_message.content))
# Out:
# 인프런에는 정말 다양한 분야의 강의가 있습니다! 어떤 분야에 관심 있으신가요? 좀 더 구체적으로 알려주시면 더 자세한 추천을 해드릴 수 있지만, 우선 인프런에서 인기 있는 강의 분야와 몇 가지 예시를 소개해 드릴게요.
#
# **인기 강의 분야:**
#
# *   **프로그래밍:**
#     *   **Python:** 파이썬 기초, 데이터 분석, 웹 개발, 머신러닝 등 다양한 수준의 강의가 있습니다. (예: "파이썬 기초 문법", "파이썬 데이터 분석 완벽 가이드")
#     *   **JavaScript:** 웹 프론트엔드 개발에 필수적인 JavaScript 강의가 많습니다. (예: "JavaScript 기초", "React.js 실전")
#     *   **Java:** 안드로이드 앱 개발, 백엔드 개발 등 Java 관련 강의도 인기 있습니다. (예: "자바 기초 문법", "Spring 프레임워크")
#     *   **C/C++:** 시스템 프로그래밍, 게임 개발 등에 사용되는 C/C++ 강의도 제공됩니다.
# *   **웹 개발:**
#     *   **프론트엔드:** HTML, CSS, JavaScript를 활용한 웹 페이지 제작 강의 (예: "HTML/CSS 기초", "React.js 실전")
#     *   **백엔드:** Node.js, Django, Spring 등 백엔드 프레임워크 사용법 강의 (예: "Node.js로 서버 만들기", "Django 웹 개발")
#     *   **웹 디자인:** UI/UX 디자인, 웹 퍼블리싱 강의 (예: "Figma를 활용한 UI/UX 디자인")
# *   **데이터 분석/머신러닝:**
#     *   **데이터 분석:** Pandas, NumPy, Scikit-learn 등 데이터 분석 라이브러리 사용법 강의 (예: "파이썬 데이터 분석 완벽 가이드")
#     *   **머신러닝:** 딥러닝, 자연어 처리, 이미지 인식 등 머신러닝 알고리즘 강의 (예: "TensorFlow를 이용한 딥러닝")
# *   **IT/기술:**
#     *   **클라우드:** AWS, Azure, GCP 등 클라우드 서비스 사용법 강의 (예: "AWS 실전 서버 구축")
#     *   **DevOps:** Docker, Kubernetes 등 DevOps 도구 사용법 강의 (예: "Docker를 이용한 컨테이너 개발")
#     *   **보안:** 웹 보안, 네트워크 보안 등 보안 관련 강의 (예: "OWASP Top 10 취약점 분석")
#     *   **정보 보안:** 윤리적 해킹, 침해 사고 대응 등 정보 보안 관련 강의
# *   **기타:**
#     *   **인공지능:** 챗봇 개발, 이미지 생성 등 인공지능 관련 강의
#     *   **게임 개발:** Unity, Unreal Engine 등 게임 엔진 사용법 강의
#     *   **마케팅:** 디지털 마케팅, SEO, 콘텐츠 마케팅 등 마케팅 관련 강의
#
# **인프런 강의 검색 방법:**
#
# 1.  **인프런 웹사이트 방문:** [https://inflearn.co.kr/](https://inflearn.co.kr/)
# 2.  **검색창 활용:** 찾고 싶은 강의 키워드를 검색창에 입력합니다. (예: "파이썬", "React", "클라우드")
# 3.  **카테고리 탐색:** 왼쪽 메뉴에서 관심 있는 카테고리를 선택하여 강의를 둘러볼 수 있습니다.
# 4.  **인기 강의 확인:** 인프런 홈페이지에서 인기 강의 목록을 확인할 수 있습니다.
#
# **어떤 분야에 관심 있으신지 알려주시면 더 자세한 강의를 추천해 드릴게요!** 예를 들어 "파이썬을 배우고 싶어요", "웹 개발 입문 강의를 찾고 있어요" 와 같이 말씀해주시면 됩니다.

# %% [markdown]
# ---
#
# open ai pricing: https://openai.com/ko-KR/api/pricing/
#
# ---
