# %% [markdown]
# ## Preprocessing
#
# - mono channel
# - 48kHz

# %%
import os

os.listdir('../static_files/suno')[:5]
# Out:
# ['31-Vochop.mp3',
#  '41-Normal Sunset.mp3',
#  '11-Let Me Go.mp3',
#  '21-what u want.mp3',
#  '61-poster 2 2.mp3']

# %%
# 1m 14.7s

import os
import librosa
import soundfile as sf

input_dir = '../static_files/suno'
output_dir = '../static_files/suno_mono'
os.makedirs(output_dir, exist_ok=True)

for filename in os.listdir(input_dir):
    if filename.lower().endswith('.mp3'):
        input_path = os.path.join(input_dir, filename)
        y, sr = librosa.load(input_path, sr=None, mono=True)
        output_path = os.path.join(output_dir, filename)
        sf.write(output_path, y, sr)

# %%
import librosa
import IPython.display as ipd
import random

mono_dir = '../static_files/suno_mono'
mp3_files = [f for f in os.listdir(mono_dir) if f.lower().endswith('.mp3')]

if mp3_files:
    sample_file = random.choice(mp3_files)
    sample_path = os.path.join(mono_dir, sample_file)
    y, sr = librosa.load(sample_path, sr=None, mono=True)
    
    # 파일 정보 출력
    print(f"파일명: {sample_file}")
    print(f"샘플링 레이트: {sr}")
    print(f"총 샘플 수: {len(y)}")
    print(f"재생 시간(초): {len(y) / sr:.2f}")
    if y.ndim == 1:
        print("이 파일은 mono입니다.")
    elif y.ndim == 2:
        print("이 파일은 stereo입니다.")
    else:
        print(f"채널 수: {y.ndim}")
    
    # 실제로 재생
    ipd.display(ipd.Audio(sample_path))
else:
    print("mp3 파일이 존재하지 않습니다.")
# Out:
# 파일명: 35-Ambiguous Neon.mp3
# 샘플링 레이트: 48000
# 총 샘플 수: 6566399
# 재생 시간(초): 136.80
# 이 파일은 mono입니다.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Embedding using laion-CLAP
#
# - using laion/larger_clap_music
# - 추출 벡터를 보니 l2 norm process 자체가 내부에 있음 (l2 normalization 필요 없음)

# %%
# 13.3s

from transformers import ClapProcessor, ClapModel
import torch
import librosa

# laion/larger_clap_music 모델과 processor 불러오기
processor = ClapProcessor.from_pretrained("laion/larger_clap_music")
model = ClapModel.from_pretrained("laion/larger_clap_music")

# CLAP 모델의 기본 sampling rate (48kHz)
TARGET_SR = 48000

embeddings = {}
for mp3_file in mp3_files:
    file_path = os.path.join(mono_dir, mp3_file)
    
    # librosa로 오디오 로드 (48kHz, mono)
    audio_data, sr = librosa.load(file_path, sr=TARGET_SR, mono=True)
    
    # processor로 전처리 (sampling_rate 명시)
    inputs = processor(
        audios=audio_data, 
        sampling_rate=TARGET_SR, 
        return_tensors="pt"
    )
    
    with torch.no_grad():
        audio_emb = model.get_audio_features(**inputs)
    
    embeddings[mp3_file] = audio_emb.cpu().numpy()
    print(f"✓ {mp3_file} - shape: {audio_emb.shape}")

print(f"\n총 {len(embeddings)}개 파일 임베딩 완료!")
# Out:
# /var/folders/hc/l5s1x0nj069bzjc37bk47xnw0000gn/T/ipykernel_52058/2903133681.py:20: FutureWarning: `audios` is deprecated and will be removed in version v4.59.0 for `ClapProcessor.__call__`. Use `audio` instead.
#   inputs = processor(
# ✓ 31-Vochop.mp3 - shape: torch.Size([1, 512])
# ✓ 55-ill go my way 3.mp3 - shape: torch.Size([1, 512])
# ✓ 9-Back and Forth.mp3 - shape: torch.Size([1, 512])
# ✓ 76-moonlight.mp3 - shape: torch.Size([1, 512])
# ✓ 84-reverb 6.mp3 - shape: torch.Size([1, 512])
# ✓ 14-plz Open the Door.mp3 - shape: torch.Size([1, 512])
# ✓ 42-Little Chaos.mp3 - shape: torch.Size([1, 512])
# ✓ 16-mongle harmonies.mp3 - shape: torch.Size([1, 512])
# ✓ 45-City Serenade.mp3 - shape: torch.Size([1, 512])
# ✓ 49-City Lights in a Broken Beat.mp3 - shape: torch.Size([1, 512])
# ✓ 3-Romance.mp3 - shape: torch.Size([1, 512])
# ✓ 37-wawa.mp3 - shape: torch.Size([1, 512])
# ✓ 58-what u saymp3.mp3 - shape: torch.Size([1, 512])
# ✓ 54-straight go my way ver 4.mp3 - shape: torch.Size([1, 512])
# ✓ 33-On Street.mp3 - shape: torch.Size([1, 512])
# ✓ 82-reverb 4.mp3 - shape: torch.Size([1, 512])
# ✓ 79-reverb.mp3 - shape: torch.Size([1, 512])
# ✓ 75-together.mp3 - shape: torch.Size([1, 512])
# ✓ 24-Chaka Waka.mp3 - shape: torch.Size([1, 512])
# ✓ 8-Magnifier.mp3 - shape: torch.Size([1, 512])
# ✓ 57-ill go my way.mp3 - shape: torch.Size([1, 512])
# ✓ 20-Latata.mp3 - shape: torch.Size([1, 512])
# ✓ 10-Happy Triangle.mp3 - shape: torch.Size([1, 512])
# ✓ 59-poster 2 1.mp3 - shape: torch.Size([1, 512])
# ✓ 78-moonlight 3.mp3 - shape: torch.Size([1, 512])
# ✓ 48-Velvet Fragments.mp3 - shape: torch.Size([1, 512])
# ✓ 36-loop in room.mp3 - shape: torch.Size([1, 512])
# ✓ 7-Daily.mp3 - shape: torch.Size([1, 512])
# ✓ 77-moonlight 2.mp3 - shape: torch.Size([1, 512])
# ✓ 70-deep night 5.mp3 - shape: torch.Size([1, 512])
# ✓ 65-depp night 1.mp3 - shape: torch.Size([1, 512])
# ✓ 15-Colorful Excuse.mp3 - shape: torch.Size([1, 512])
# ✓ 50-meaning.mp3 - shape: torch.Size([1, 512])
# ✓ 4-Do Re Do Re Do.mp3 - shape: torch.Size([1, 512])
# ✓ 73-deep night 8.mp3 - shape: torch.Size([1, 512])
# ✓ 12-mola.mp3 - shape: torch.Size([1, 512])
# ✓ 44-Moonlight Bounce.mp3 - shape: torch.Size([1, 512])
# ✓ 29-Tick Tat.mp3 - shape: torch.Size([1, 512])
#
# 총 84개 파일 임베딩 완료!

# %%
embeddings['31-Vochop.mp3'].shape
# Out:
# (1, 512)

# %%
inputs['input_features'].shape
# Out:
# torch.Size([1, 1, 1001, 64])

# %%
import numpy as np

# L2 Normalization 적용
normalized_embeddings = {}
for fname, emb in embeddings.items():
    # emb shape: (1, 512) -> squeeze해서 (512,)로 만들고 normalize
    emb_flat = emb.squeeze()  # (512,)
    l2_norm = np.linalg.norm(emb_flat)
    normalized_emb = emb_flat / l2_norm
    normalized_embeddings[fname] = normalized_emb

# 검증: L2 norm이 1인지 확인
sample_key = list(normalized_embeddings.keys())[0]
sample_norm = np.linalg.norm(normalized_embeddings[sample_key])
print(f"샘플 '{sample_key}'의 L2 norm: {sample_norm:.6f}")
print(f"임베딩 shape: {normalized_embeddings[sample_key].shape}")
# Out:
# 샘플 '31-Vochop.mp3'의 L2 norm: 1.000000
# 임베딩 shape: (512,)

# %%
normalized_embeddings['31-Vochop.mp3']
# Out:
# array([-0.00677449,  0.00303425,  0.13320889, -0.04869   , -0.02569649,
#         0.01157782, -0.03957724, -0.03620983, -0.03711814,  0.05846758,
#         0.05416006, -0.01636868, -0.08753783,  0.01269977, -0.00771324,
#        -0.05010893,  0.07501113,  0.09401571, -0.04398833, -0.01495767,
#         0.0402547 ,  0.02504187,  0.03780269, -0.06393874, -0.05887164,
#         0.04821058, -0.00996679,  0.00690144, -0.04429559,  0.03789781,
#         0.03744894,  0.10529441, -0.06303916, -0.04891729,  0.00898471,
#        -0.05593539, -0.03597819,  0.01018485, -0.04394026,  0.03854926,
#         0.09427232, -0.00127043,  0.01309529,  0.01019805, -0.04769791,
#        -0.02716067, -0.06406462,  0.06911797, -0.07344545, -0.04450381,
#        -0.04635184,  0.00692972, -0.00756504, -0.00021641, -0.02697095,
#         0.00623455, -0.01825501, -0.04850756,  0.02832927,  0.01383859,
#         0.06064751, -0.02506255, -0.0016869 , -0.07165688, -0.05812662,
#        -0.02703802, -0.02195805,  0.04951827, -0.05282455, -0.0255073 ,
#         0.01040559,  0.01206895,  0.03984503,  0.03407324, -0.01367815,
#         0.06899526,  0.0018234 ,  0.0001829 , -0.05083515,  0.01718915,
#         0.00443368,  0.00483141,  0.0407748 , -0.06199603,  0.01418228,
#        -0.12035768, -0.03208147, -0.0372813 , -0.08686136, -0.01145067,
#         0.08658512, -0.00494067,  0.0185032 , -0.01569523,  0.017932  ,
#         0.04295663, -0.03259888, -0.03775419, -0.00072134,  0.02871183,
#        -0.03715452, -0.04022941, -0.00510708,  0.00921404,  0.05774874,
#        -0.06067306,  0.01741015,  0.01917965,  0.02555959,  0.01981576,
#         0.0114799 ,  0.05909432,  0.05713106, -0.04650402,  0.07140189,
#         0.0125027 , -0.01201751, -0.01726248,  0.01175662,  0.00829538,
#         0.01133254,  0.07289007,  0.07755496, -0.05996725,  0.00051462,
#         0.00454061,  0.00382338, -0.04041042, -0.02312834, -0.02579852,
#         0.00881078, -0.00681581,  0.02857929,  0.01824194,  0.03125535,
#         0.05754289, -0.07054187,  0.06801975, -0.01431581, -0.04069348,
#        -0.02138202,  0.05753387, -0.01418433,  0.00879153, -0.07712118,
#         0.01894536, -0.0132348 , -0.02651985,  0.02874253, -0.02923655,
#         0.00741334,  0.00998355, -0.03275024, -0.02755088,  0.02311748,
#         0.08876766, -0.05987957, -0.06019049,  0.02309372, -0.0428281 ,
#         0.02015379, -0.06622733,  0.00390179,  0.06126358,  0.09979121,
#        -0.05793356, -0.04673272,  0.01122392,  0.00713037, -0.02102676,
#        -0.02872184,  0.01461218,  0.03720428, -0.00030843, -0.00828618,
#         -0.04901016, -0.00449562,  0.01936576,  0.02257787,  0.01802341,
#          0.06802636,  0.01260621,  0.04214438, -0.02625757,  0.06830405,
#          0.06121234,  0.02204404, -0.08574112, -0.02994707, -0.03927702,
#          0.03211698,  0.03145443, -0.02513526, -0.0290784 ,  0.01044477,
#         -0.05371493, -0.02208011, -0.07361205, -0.04938716, -0.05270011,
#         -0.0888684 ,  0.0207103 , -0.03216339,  0.04807289, -0.01589248,
#         -0.05103151, -0.01728718,  0.08542833,  0.01412306, -0.09937174,
#          0.04692406,  0.08231413]], dtype=float32)

# %%
# L2 Normalization 전후 벡터 크기 비교
sample_key = '31-Vochop.mp3'

# 원본 임베딩
original_emb = embeddings[sample_key].squeeze()
original_l2_norm = np.linalg.norm(original_emb)

# 정규화된 임베딩
normalized_emb = normalized_embeddings[sample_key]
normalized_l2_norm = np.linalg.norm(normalized_emb)

print(f"📁 파일: {sample_key}")
print(f"{'='*40}")
print(f"🔹 원본 벡터 L2 norm:     {original_l2_norm:.6f}")
print(f"🔹 정규화 후 L2 norm:     {normalized_l2_norm:.6f}")
print(f"{'='*40}")
print(f"📐 벡터 차원: {original_emb.shape[0]}")
print(f"📉 축소 비율: {normalized_l2_norm / original_l2_norm:.6f}")
# Out:
# 📁 파일: 31-Vochop.mp3
# ========================================
# 🔹 원본 벡터 L2 norm:     1.000000
# 🔹 정규화 후 L2 norm:     1.000000
# ========================================
# 📐 벡터 차원: 512
# 📉 축소 비율: 1.000000

# %% [markdown]
# ## Write Embeddings to supabase

# %%
# 키를 id만 남기고, embedding을 Supabase에 저장하기 쉬운 형태(list)로 변환
supabase_data = []

for filename, emb in embeddings.items():
    # "31-Vochop.mp3" -> "31"
    music_id = filename.split('-')[0]
    
    # numpy array (1, 512) -> list (512,)
    embedding_list = emb.squeeze().tolist()
    
    supabase_data.append({
        "id": int(music_id),
        "embedding": embedding_list
    })

# 정렬 (id 기준)
supabase_data.sort(key=lambda x: x["id"])

# 결과 확인
print(f"총 {len(supabase_data)}개 데이터 변환 완료!")
print(f"\n샘플 데이터:")
print(f"  - id: {supabase_data[0]['id']}")
print(f"  - embedding 타입: {type(supabase_data[0]['embedding'])}")
print(f"  - embedding 길이: {len(supabase_data[0]['embedding'])}")
print(f"  - embedding[:5]: {supabase_data[0]['embedding'][:5]}")
# Out:
# 총 84개 데이터 변환 완료!
#
# 샘플 데이터:
#   - id: 3
#   - embedding 타입: <class 'list'>
#   - embedding 길이: 512
#   - embedding[:5]: [-0.007643065880984068, 0.0025495439767837524, 0.12741483747959137, -0.03734913840889931, -0.02148122899234295]

# %%
supabase_data[0]
# Out:
# {'id': 3,
#  'embedding': [-0.007643065880984068,
#   0.0025495439767837524,
#   0.12741483747959137,
#   -0.03734913840889931,
#   -0.02148122899234295,
#   0.01883510872721672,
#   -0.035042911767959595,
#   -0.0370391346514225,
#   -0.03975120186805725,
#   0.07134031504392624,
#   0.05242178589105606,
#   -0.014452211558818817,
#   -0.09894503653049469,
#   0.03277325630187988,
#   0.01660280115902424,
#   -0.053961288183927536,
#   0.06681770086288452,
